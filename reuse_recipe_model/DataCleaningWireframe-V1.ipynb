# %%
facts  = ""
with open("recipe_model_wireframe_demo.pl","r") as file:
    for l in file:
        #if l.strip().startswith("%"):
        #    continue
        
        facts += l.strip() + "\n"

# %%
# !clingo recipe_model_wireframe_demo.pl
# Out:
# clingo version 5.5.0
# Reading from recipe_model_wireframe_demo.pl
# Solving...
# Answer: 1
# accumulated_dq_problem(column_state(c1,2),unknown_char) accumulated_dq_problem(column_state(c2,1),unknown_char) accumulated_dq_problem(column_state(c2,1),lower_case) accumulated_dq_problem(column_state(c3,1),lower_case) accumulated_dq_problem(column_state(c2,t2_1),unknown_char) accumulated_dq_problem(column_state(c2,t2_1),lower_case) accumulated_dq_problem(column_state(c2,t2_2),lower_case) accumulated_dq_problem(column_state(c2,t2_3),lower_case) accumulated_dq_problem(column_state(c3,2),lower_case) accumulated_dq_problem(column_state(c2,t2_4),lower_case) accumulated_dq_problem(column_state(c1,1),null_value) accumulated_dq_problem(column_state(c1,1),split_name) accumulated_dq_problem(column_state(c1,1),unknown_char)
# SATISFIABLE
#
# Models       : 1
# Calls        : 1
# Time         : 0.005s (Solving: 0.00s 1st Model: 0.00s Unsat: 0.00s)
# CPU Time     : 0.005s

# %%
#facts

# %%
from clingo.symbol import Number
from clingo.control import Control

ctl = Control()
ctl.add("base", [], facts)

# %%
ctl.ground([("base", [])])
solver = ctl.solve(yield_=True)

# %%
output = []
for x in solver:
    output.append(x)

# %%
df_output = {}
df_output_str = {}
for s in x.context.symbolic_atoms.signatures:
    #print(s)
    df_output[(s[0],s[1])] = []
    df_output_str[(s[0],s[1])] = []
    for y in x.context.symbolic_atoms.by_signature(s[0],s[1]):
        temp_tuple = [y.symbol.name]
        temp_tuple = temp_tuple + [str(z) for z in y.symbol.arguments]
        df_output[(s[0],s[1])].append(y.symbol)
        df_output_str[(s[0],s[1])].append(temp_tuple)

# %%
x.context.symbolic_atoms.signatures
# Out:
# [('column_schema', 3, True),
#  ('workflow_step', 4, True),
#  ('step_input_schema', 4, True),
#  ('workflow_input_violation', 4, True),
#  ('step_input_blueprint', 4, True),
#  ('step_input_satisfiable', 6, True),
#  ('step_output_schema', 4, True),
#  ('workflow_output_violation', 4, True),
#  ('dq_problem', 2, True),
#  ('step_dq_problem', 3, True),
#  ('dq_problem_violation', 3, True),
#  ('process', 2, True),
#  ('dq_proxy', 3, True),
#  ('recipe_edge', 3, True),
#  ('recipe_path', 4, True),
#  ('process_edge', 4, True),
#  ('column_edge', 3, True),
#  ('column_path', 3, True),
#  ('select_path', 3, True),
#  ('accumulated_dq_handling', 2, True),
#  ('accumulated_dq_problem', 2, True),
#  ('column', 4, True),
#  ('input_process', 3, True),
#  ('output_process', 3, True),
#  ('parameter', 4, True)]

# %%
import pandas as pd
pd.DataFrame(df_output_str[("step_input_schema",4)])
# Out:
#                     0  1                      2   3  \
# 0   step_input_schema  1     column_state(c1,1)  p1
# 1   step_input_schema  1     column_state(c1,1)  p1
# 2   step_input_schema  2     column_state(c2,1)  p1
# 3   step_input_schema  2     column_state(c2,1)  p1
# 4   step_input_schema  2     column_state(c2,1)  p5
# 5   step_input_schema  2     column_state(c2,1)  p5
# 6   step_input_schema  3  column_state(c2,t2_2)  p6
# 7   step_input_schema  3  column_state(c2,t2_2)  p6
# 8   step_input_schema  4  column_state(c2,t2_2)  p4
# 9   step_input_schema  4  column_state(c2,t2_2)  p4
# 10  step_input_schema  4     column_state(c3,1)  p4
# 11  step_input_schema  4     column_state(c3,1)  p4
# 12  step_input_schema  5     column_state(c3,2)  p8
# 13  step_input_schema  5     column_state(c3,2)  p8
#
#                                      4
# 0    column_schema(cs1,name,full_name)
# 1    column_schema(cs1,data_type,text)
# 2   column_schema(cs2,name,first_name)
# 3    column_schema(cs2,data_type,text)
# 4   column_schema(cs2,name,first_name)
# 5    column_schema(cs2,data_type,text)
# 6   column_schema(cs2,name,first_name)
# 7    column_schema(cs2,data_type,text)
# 8   column_schema(cs2,name,first_name)
# 9    column_schema(cs2,data_type,text)
# 10   column_schema(cs3,name,last_name)
# 11   column_schema(cs3,data_type,text)
# 12   column_schema(cs3,name,last_name)
# 13   column_schema(cs3,data_type,text)

# %%
import pandas as pd
pd.DataFrame(df_output_str[("workflow_step",4)])
# Out:
#                 0  1                      2   3                      4
# 0   workflow_step  1     column_state(c1,1)  p1     column_state(c1,2)
# 1   workflow_step  1     column_state(c1,1)  p1     column_state(c2,1)
# 2   workflow_step  1     column_state(c1,1)  p1     column_state(c3,1)
# 3   workflow_step  2     column_state(c2,1)  p1  column_state(c2,t2_1)
# 4   workflow_step  2     column_state(c2,1)  p5  column_state(c2,t2_2)
# 5   workflow_step  3  column_state(c2,t2_2)  p6  column_state(c2,t2_3)
# 6   workflow_step  4     column_state(c3,1)  p4     column_state(c3,2)
# 7   workflow_step  4  column_state(c2,t2_2)  p4  column_state(c2,t2_4)
# 8   workflow_step  4     column_state(c3,1)  p4     column_state(c5,1)
# 9   workflow_step  4  column_state(c2,t2_2)  p4     column_state(c5,1)
# 10  workflow_step  5     column_state(c3,2)  p8     column_state(c3,3)

# %%
import pandas as pd
pd.DataFrame(df_output_str[("workflow_input_violation",4)])
# Out:
#                           0  1           2   3  \
# 0  workflow_input_violation  2  unexpected  p1
# 1  workflow_input_violation  2  unexpected  p5
# 2  workflow_input_violation  3  unexpected  p6
# 3  workflow_input_violation  5  unexpected  p8
# 4  workflow_input_violation  2     missing  p1
# 5  workflow_input_violation  3     missing  p6
#
#                                    4
# 0                 column_state(c2,1)
# 1                 column_state(c2,1)
# 2              column_state(c2,t2_2)
# 3                 column_state(c3,2)
# 4  column_schema(cs1,name,full_name)
# 5       column_schema(cs4,name,date)

# %%
import pandas as pd
pd.DataFrame(df_output_str[("workflow_output_violation",4)])
# Out:
#                            0  1        2   3  \
# 0  workflow_output_violation  2  missing  p1
# 1  workflow_output_violation  2  missing  p1
# 2  workflow_output_violation  3  missing  p6
#
#                                      4
# 0    column_schema(cs1,name,full_name)
# 1    column_schema(cs3,name,last_name)
# 2  column_schema(cs8,data_type,number)

# %%
df_output[("step_input_schema",4)]
# Out:
# [Function('step_input_schema', [Number(1), Function('column_state', [Function('c1', [], True), Number(1)], True), Function('p1', [], True), Function('column_schema', [Function('cs1', [], True), Function('name', [], True), Function('full_name', [], True)], True)], True),
#  Function('step_input_schema', [Number(1), Function('column_state', [Function('c1', [], True), Number(1)], True), Function('p1', [], True), Function('column_schema', [Function('cs1', [], True), Function('data_type', [], True), Function('text', [], True)], True)], True),
#  Function('step_input_schema', [Number(2), Function('column_state', [Function('c2', [], True), Number(1)], True), Function('p1', [], True), Function('column_schema', [Function('cs2', [], True), Function('name', [], True), Function('first_name', [], True)], True)], True),
#  Function('step_input_schema', [Number(2), Function('column_state', [Function('c2', [], True), Number(1)], True), Function('p1', [], True), Function('column_schema', [Function('cs2', [], True), Function('data_type', [], True), Function('text', [], True)], True)], True),
#  Function('step_input_schema', [Number(2), Function('column_state', [Function('c2', [], True), Number(1)], True), Function('p5', [], True), Function('column_schema', [Function('cs2', [], True), Function('name', [], True), Function('first_name', [], True)], True)], True),
#  Function('step_input_schema', [Number(2), Function('column_state', [Function('c2', [], True), Number(1)], True), Function('p5', [], True), Function('column_schema', [Function('cs2', [], True), Function('data_type', [], True), Function('text', [], True)], True)], True),
#  Function('step_input_schema', [Number(3), Function('column_state', [Function('c2', [], True), Function('t2_2', [], True)], True), Function('p6', [], True), Function('column_schema', [Function('cs2', [], True), Function('name', [], True), Function('first_name', [], True)], True)], True),
#  Function('step_input_schema', [Number(3), Function('column_state', [Function('c2', [], True), Function('t2_2', [], True)], True), Function('p6', [], True), Function('column_schema', [Function('cs2', [], True), Function('data_type', [], True), Function('text', [], True)], True)], True),
#  Function('step_input_schema', [Number(4), Function('column_state', [Function('c2', [], True), Function('t2_2', [], True)], True), Function('p4', [], True), Function('column_schema', [Function('cs2', [], True), Function('name', [], True), Function('first_name', [], True)], True)], True),
#  Function('step_input_schema', [Number(4), Function('column_state', [Function('c2', [], True), Function('t2_2', [], True)], True), Function('p4', [], True), Function('column_schema', [Function('cs2', [], True), Function('data_type', [], True), Function('text', [], True)], True)], True),
#  Function('step_input_schema', [Number(4), Function('column_state', [Function('c3', [], True), Number(1)], True), Function('p4', [], True), Function('column_schema', [Function('cs3', [], True), Function('name', [], True), Function('last_name', [], True)], True)], True),
#  Function('step_input_schema', [Number(4), Function('column_state', [Function('c3', [], True), Number(1)], True), Function('p4', [], True), Function('column_schema', [Function('cs3', [], True), Function('data_type', [], True), Function('text', [], True)], True)], True),
#  Function('step_input_schema', [Number(5), Function('column_state', [Function('c3', [], True), Number(2)], True), Function('p8', [], True), Function('column_schema', [Function('cs3', [], True), Function('name', [], True), Function('last_name', [], True)], True)], True),
#  Function('step_input_schema', [Number(5), Function('column_state', [Function('c3', [], True), Number(2)], True), Function('p8', [], True), Function('column_schema', [Function('cs3', [], True), Function('data_type', [], True), Function('text', [], True)], True)], True)]

# %%
df_output_str[("output_process",3)]
# Out:
# [['output_process', 'p1', '1', 'cs1'],
#  ['output_process', 'p1', '2', 'cs2'],
#  ['output_process', 'p1', '3', 'cs3'],
#  ['output_process', 'p2', '1', 'cs5'],
#  ['output_process', 'p3', '1', 'cs5'],
#  ['output_process', 'p4', '1', 'cs5'],
#  ['output_process', 'p5', '1', 'cs5'],
#  ['output_process', 'p6', '1', 'cs8'],
#  ['output_process', 'p7', '1', 'cs7'],
#  ['output_process', 'p8', '1', 'cs5']]

# %%
df_output_str[("process",2)]
# Out:
# [['process', 'p1', 'split_name'],
#  ['process', 'p2', 'upper_case'],
#  ['process', 'p3', 'rename_col'],
#  ['process', 'p4', 'merge_col'],
#  ['process', 'p5', 'normalize_char'],
#  ['process', 'p6', 'normalize_date'],
#  ['process', 'p7', 'fixed_ssn'],
#  ['process', 'p8', 'lower_case']]

# %%
df_output_str[("column_schema",3)]
# Out:
# [['column_schema', 'cs1', 'name', 'full_name'],
#  ['column_schema', 'cs1', 'data_type', 'text'],
#  ['column_schema', 'cs2', 'name', 'first_name'],
#  ['column_schema', 'cs2', 'data_type', 'text'],
#  ['column_schema', 'cs3', 'name', 'last_name'],
#  ['column_schema', 'cs3', 'data_type', 'text'],
#  ['column_schema', 'cs4', 'name', 'date'],
#  ['column_schema', 'cs4', 'data_type', 'text'],
#  ['column_schema', 'cs5', 'data_type', 'text'],
#  ['column_schema', 'cs6', 'name', 'ssn'],
#  ['column_schema', 'cs6', 'data_type', 'text'],
#  ['column_schema', 'cs7', 'name', 'ssn'],
#  ['column_schema', 'cs7', 'data_type', 'number'],
#  ['column_schema', 'cs8', 'data_type', 'number']]

# %%
# visualize using graphviz yw layout

nodes_def = """
digraph "[stackcollapse]" {
node [style=filled fillcolor="#f8f8f8"]
"""

edge_def = ""

# workflow template gv format

header = """
/* Start of top-level graph */
digraph Workflow {
rankdir=TB

/* Start of double cluster for drawing box around nodes in workflow */
subgraph cluster_workflow_box_outer { label=""; penwidth=0
subgraph cluster_workflow_box_inner { label=""; penwidth=0
"""

single_process = """
/* Style for nodes representing atomic programs in workflow */
node[shape=box style=filled fillcolor="#CCFFCC" peripheries=1 fontname=Helvetica]

/* Nodes representing atomic programs in workflow */
"""
#state_4 [shape=record rankdir=LR label="{<f0> step 4 (to_date) | grel\:value.replace(/\\/i,'') | 16492 cells changed}"];


side_b_process = """
node[shape=box style=filled fillcolor="#CCCCFF" peripheries=1 fontname=Helvetica]
"""
#state_5 [shape=record rankdir=LR label="{<f0> state_5 |<f1> core/mass-edit\nclustering\ngroup clustering 4 processes}"];

side_b_data = """
node[shape=box style="rounded,filled" fillcolor="#FFDDDD" peripheries=1 fontname=Helvetica]
"""

side_a_data = """
node[shape=box style="rounded,filled" fillcolor="#CCFFFF" peripheries=1 fontname=Helvetica]
"""


freq_pattern_nodes = """
node[shape=box style=filled fillcolor="#CCFFFF" peripheries=1 fontname=Helvetica]
"""
#state_5 [shape=record rankdir=LR label="{<f0> state_5 |<f1> core/mass-edit\nclustering\ngroup clustering 4 processes}"];

column_nodes = """
/* Style for nodes representing non-parameter data channels in workflow */
node[shape=box style="rounded,filled" fillcolor="#FFFFCC" peripheries=1 fontname=Helvetica]

/* Nodes for non-parameter data channels in workflow */
"""
#"col12_0-date" [shape=record rankdir=LR label="{<f0> date_0 }"]

parameters_nodes = """
/* Style for nodes representing parameter channels in workflow */
node[shape=box style="rounded,filled" fillcolor="#FCFCFC" peripheries=1 fontname=Helvetica]

/* Nodes representing parameter channels in workflow */
"""

edges = """
/* Edges representing connections between programs and channels */
"""
#"col12_0-date" -> state_4


footer = """
/* End of double cluster for drawing box around nodes in workflow */
}}

/* End of top-level graph */
}
"""

# process nodes
for p in df_output_str[("process",2)]:
    single_process+='''
    "{pid}" [shape=record rankdir=LR label="{{<f0> {pid} ({process_name}) }}"];
    '''.format(pid=p[1],process_name=p[2])

# schema nodes
for cs in df_output_str[("column_schema",3)]:    
    column_nodes+="""
    "{node_name}" [shape=record rankdir=LR label="{{<f0> {label} }}"]
    """.format(node_name=cs[1],label=cs[1])
    parameters_nodes+="""
    "{node_name}" [shape=record rankdir=LR label="{{<f0> {label} }}"]
    """.format(node_name=cs[1]+"_"+cs[2],label=cs[3])
    edges+="""
        {input} -> {output} [label="{data}" weight=14 color="#b26e37" tooltip="" labeltooltip=""]    
    """.format(input=cs[1],output=cs[1]+"_"+cs[2],data=cs[2])   

# edge input output
for inp in df_output_str[("input_process",3)]:                    
    edges+="""
        {input} -> {output} [label="{data}" weight=14 color="#b26e37" tooltip="" labeltooltip=""]    
    """.format(input=inp[3],output=inp[1],data="")            

for out in df_output_str[("output_process",3)]:                    
    edges+="""
        {input} -> {output} [label="{data}" weight=14 color="#b26e37" tooltip="" labeltooltip=""]    
    """.format(input=out[1],output=out[3],data="")            

                        

gv_string = header+single_process+column_nodes+parameters_nodes+side_b_process+side_a_data+side_b_data+freq_pattern_nodes+edges+footer

# %%
print(gv_string)
# Out:
# /* Start of top-level graph */
# digraph Workflow {
# rankdir=TB
#
# /* Start of double cluster for drawing box around nodes in workflow */
# subgraph cluster_workflow_box_outer { label=""; penwidth=0
# subgraph cluster_workflow_box_inner { label=""; penwidth=0
#
# /* Style for nodes representing atomic programs in workflow */
# node[shape=box style=filled fillcolor="#CCFFCC" peripheries=1 fontname=Helvetica]
#
# /* Nodes representing atomic programs in workflow */
#
#     "p1" [shape=record rankdir=LR label="{<f0> p1 (split_name) }"];
#
#     "p2" [shape=record rankdir=LR label="{<f0> p2 (upper_case) }"];
#
#     "p3" [shape=record rankdir=LR label="{<f0> p3 (rename_col) }"];
#
#     "p4" [shape=record rankdir=LR label="{<f0> p4 (merge_col) }"];
#
#     "p5" [shape=record rankdir=LR label="{<f0> p5 (normalize_char) }"];
#
#     "p6" [shape=record rankdir=LR label="{<f0> p6 (normalize_date) }"];
#
#     "p7" [shape=record rankdir=LR label="{<f0> p7 (fixed_ssn) }"];
#
#     "p8" [shape=record rankdir=LR label="{<f0> p8 (lower_case) }"];
#
# /* Style for nodes representing non-parameter data channels in workflow */
# node[shape=box style="rounded,filled" fillcolor="#FFFFCC" peripheries=1 fontname=Helvetica]
#
# /* Nodes for non-parameter data channels in workflow */
#
#     "cs1" [shape=record rankdir=LR label="{<f0> cs1 }"]
#
#     "cs1" [shape=record rankdir=LR label="{<f0> cs1 }"]
#
#     "cs2" [shape=record rankdir=LR label="{<f0> cs2 }"]
#
#     "cs2" [shape=record rankdir=LR label="{<f0> cs2 }"]
#
#     "cs3" [shape=record rankdir=LR label="{<f0> cs3 }"]
#
#     "cs3" [shape=record rankdir=LR label="{<f0> cs3 }"]
#
#     "cs4" [shape=record rankdir=LR label="{<f0> cs4 }"]
#
#     "cs4" [shape=record rankdir=LR label="{<f0> cs4 }"]
#
#     "cs5" [shape=record rankdir=LR label="{<f0> cs5 }"]
#
#     "cs6" [shape=record rankdir=LR label="{<f0> cs6 }"]
#
#     "cs6" [shape=record rankdir=LR label="{<f0> cs6 }"]
#
#     "cs7" [shape=record rankdir=LR label="{<f0> cs7 }"]
#
#     "cs7" [shape=record rankdir=LR label="{<f0> cs7 }"]
#
#     "cs8" [shape=record rankdir=LR label="{<f0> cs8 }"]
#
# /* Style for nodes representing parameter channels in workflow */
# node[shape=box style="rounded,filled" fillcolor="#FCFCFC" peripheries=1 fontname=Helvetica]
#
# /* Nodes representing parameter channels in workflow */
#
#     "cs1_name" [shape=record rankdir=LR label="{<f0> full_name }"]
#
#     "cs1_data_type" [shape=record rankdir=LR label="{<f0> text }"]
#
#     "cs2_name" [shape=record rankdir=LR label="{<f0> first_name }"]
#
#     "cs2_data_type" [shape=record rankdir=LR label="{<f0> text }"]
#
#     "cs3_name" [shape=record rankdir=LR label="{<f0> last_name }"]
#
#     "cs3_data_type" [shape=record rankdir=LR label="{<f0> text }"]
#
#     "cs4_name" [shape=record rankdir=LR label="{<f0> date }"]
#
#     "cs4_data_type" [shape=record rankdir=LR label="{<f0> text }"]
#
#     "cs5_data_type" [shape=record rankdir=LR label="{<f0> text }"]
#
#     "cs6_name" [shape=record rankdir=LR label="{<f0> ssn }"]
#
#     "cs6_data_type" [shape=record rankdir=LR label="{<f0> text }"]
#
#     "cs7_name" [shape=record rankdir=LR label="{<f0> ssn }"]
#
#     "cs7_data_type" [shape=record rankdir=LR label="{<f0> number }"]
#
#     "cs8_data_type" [shape=record rankdir=LR label="{<f0> number }"]
#
# node[shape=box style=filled fillcolor="#CCCCFF" peripheries=1 fontname=Helvetica]
#
# node[shape=box style="rounded,filled" fillcolor="#CCFFFF" peripheries=1 fontname=Helvetica]
#
# node[shape=box style="rounded,filled" fillcolor="#FFDDDD" peripheries=1 fontname=Helvetica]
#
# node[shape=box style=filled fillcolor="#CCFFFF" peripheries=1 fontname=Helvetica]
#
# /* Edges representing connections between programs and channels */
#
#         cs1 -> cs1_name [label="name" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#         cs1 -> cs1_data_type [label="data_type" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#         cs2 -> cs2_name [label="name" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#         cs2 -> cs2_data_type [label="data_type" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#         cs3 -> cs3_name [label="name" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#         cs3 -> cs3_data_type [label="data_type" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#         cs4 -> cs4_name [label="name" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#         cs4 -> cs4_data_type [label="data_type" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#         cs5 -> cs5_data_type [label="data_type" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#         cs6 -> cs6_name [label="name" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#         cs6 -> cs6_data_type [label="data_type" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#         cs7 -> cs7_name [label="name" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#         cs7 -> cs7_data_type [label="data_type" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#         cs8 -> cs8_data_type [label="data_type" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#         cs1 -> p1 [label="" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#         cs5 -> p2 [label="" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#         cs5 -> p3 [label="" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#         cs2 -> p4 [label="" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#         cs3 -> p4 [label="" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#         cs5 -> p5 [label="" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#         cs4 -> p6 [label="" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#         cs6 -> p7 [label="" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#         cs5 -> p8 [label="" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#         p1 -> cs1 [label="" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#         p1 -> cs2 [label="" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#         p1 -> cs3 [label="" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#         p2 -> cs5 [label="" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#         p3 -> cs5 [label="" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#         p4 -> cs5 [label="" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#         p5 -> cs5 [label="" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#         p6 -> cs8 [label="" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#         p7 -> cs7 [label="" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#         p8 -> cs5 [label="" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
# /* End of double cluster for drawing box around nodes in workflow */
# }}
#
# /* End of top-level graph */
# }

# %%
from IPython.display import Image
def generate_pdf(gv_string,filename="temp"):
    input = filename+".gv"
    with open(input,"w") as file:
        file.write(gv_string)
    output = filename+".png"    
    # !dot -Tpng -o $output $input 
    return Image(filename=output)

# %%
generate_pdf(gv_string,"process_model")

# %% [markdown]
# # workflow step (wireframe)

# %%
df_output_str[("workflow_step",4)]
# Out:
# [['workflow_step', '1', 'column_state(c1,1)', 'p1', 'column_state(c1,2)'],
#  ['workflow_step', '1', 'column_state(c1,1)', 'p1', 'column_state(c2,1)'],
#  ['workflow_step', '1', 'column_state(c1,1)', 'p1', 'column_state(c3,1)'],
#  ['workflow_step', '2', 'column_state(c2,1)', 'p1', 'column_state(c2,t2_1)'],
#  ['workflow_step', '2', 'column_state(c2,1)', 'p5', 'column_state(c2,t2_2)'],
#  ['workflow_step',
#   '3',
#   'column_state(c2,t2_2)',
#   'p6',
#   'column_state(c2,t2_3)'],
#  ['workflow_step', '4', 'column_state(c3,1)', 'p4', 'column_state(c3,2)'],
#  ['workflow_step',
#   '4',
#   'column_state(c2,t2_2)',
#   'p4',
#   'column_state(c2,t2_4)'],
#  ['workflow_step', '4', 'column_state(c3,1)', 'p4', 'column_state(c5,1)'],
#  ['workflow_step', '4', 'column_state(c2,t2_2)', 'p4', 'column_state(c5,1)'],
#  ['workflow_step', '5', 'column_state(c3,2)', 'p8', 'column_state(c3,3)']]

# %%
# visualize using graphviz yw layout

nodes_def = """
digraph "[stackcollapse]" {
node [style=filled fillcolor="#f8f8f8"]
"""

edge_def = ""

# workflow template gv format

header = """
/* Start of top-level graph */
digraph Workflow {
rankdir=TB

/* Start of double cluster for drawing box around nodes in workflow */
subgraph cluster_workflow_box_outer { label=""; penwidth=0
subgraph cluster_workflow_box_inner { label=""; penwidth=0
"""

single_process = """
/* Style for nodes representing atomic programs in workflow */
node[shape=box style=filled fillcolor="#CCFFCC" peripheries=1 fontname=Helvetica]

/* Nodes representing atomic programs in workflow */
"""
#state_4 [shape=record rankdir=LR label="{<f0> step 4 (to_date) | grel\:value.replace(/\\/i,'') | 16492 cells changed}"];


side_b_process = """
node[shape=box style=filled fillcolor="#CCCCFF" peripheries=1 fontname=Helvetica]
"""
#state_5 [shape=record rankdir=LR label="{<f0> state_5 |<f1> core/mass-edit\nclustering\ngroup clustering 4 processes}"];

side_b_data = """
node[shape=box style="rounded,filled" fillcolor="#FFDDDD" peripheries=1 fontname=Helvetica]
"""

side_a_data = """
node[shape=box style="rounded,filled" fillcolor="#CCFFFF" peripheries=1 fontname=Helvetica]
"""

freq_pattern_nodes = """
node[shape=box style=filled fillcolor="#CCFFFF" peripheries=1 fontname=Helvetica]
"""
#state_5 [shape=record rankdir=LR label="{<f0> state_5 |<f1> core/mass-edit\nclustering\ngroup clustering 4 processes}"];

column_nodes = """
/* Style for nodes representing non-parameter data channels in workflow */
node[shape=box style="rounded,filled" fillcolor="#FFFFCC" peripheries=1 fontname=Helvetica]

/* Nodes for non-parameter data channels in workflow */
"""
#"col12_0-date" [shape=record rankdir=LR label="{<f0> date_0 }"]

parameters_nodes = """
/* Style for nodes representing parameter channels in workflow */
node[shape=box style="rounded,filled" fillcolor="#FCFCFC" peripheries=1 fontname=Helvetica]

/* Nodes representing parameter channels in workflow */
"""

edges = """
/* Edges representing connections between programs and channels */
"""
#"col12_0-date" -> state_4


footer = """
/* End of double cluster for drawing box around nodes in workflow */
}}

/* End of top-level graph */
}
"""

node_col = set()
node_step = set()
node_edges = set()

for s,fn in zip(df_output_str[("workflow_step",4)],df_output[("workflow_step",4)]):
    if s[2] not in node_col:
        column_nodes+="""
        "{node_name}" [shape=record rankdir=LR label="{{<f0> {label} }}"]
        """.format(node_name=s[2],label=s[2])
        node_col.add(s[2])
        

    if s[4] not in node_col:
        column_nodes+="""
        "{node_name}" [shape=record rankdir=LR label="{{<f0> {label} }}"]
        """.format(node_name=s[4],label=s[4])
        node_col.add(s[4])
        
        
    if s[1]+"_"+s[3] not in node_step:
        single_process+='''
        "{pid}" [shape=record rankdir=LR label="{{<f0> step {step_id} ({process_name}) }}"];
        '''.format(pid=s[1]+"_"+s[3],step_id=s[1],process_name=s[3])
        node_step.add(s[1]+"_"+s[3])
        
    
    if s[2]+"_"+s[1]+"_"+s[3] not in node_edges:
        edges+="""
            "{input}" -> "{output}" [label="{data}" weight=14 color="#b26e37" tooltip="" labeltooltip=""]    
        """.format(input=s[2],output=s[1]+"_"+s[3],data="")
        node_edges.add(s[2]+"_"+s[1]+"_"+s[3])
    
    if s[1]+"_"+s[3]+"_"+s[4] not in node_edges:
        edges+="""
            "{input}" -> "{output}" [label="{data}" weight=14 color="#b26e37" tooltip="" labeltooltip=""]    
        """.format(input=s[1]+"_"+s[3],output=s[4],data="") 
        node_edges.add(s[1]+"_"+s[3]+"_"+s[4])
        
gv_string = header+single_process+column_nodes+parameters_nodes+side_b_process+side_a_data+side_b_data+freq_pattern_nodes+edges+footer

# %%
print(gv_string)
# Out:
# /* Start of top-level graph */
# digraph Workflow {
# rankdir=TB
#
# /* Start of double cluster for drawing box around nodes in workflow */
# subgraph cluster_workflow_box_outer { label=""; penwidth=0
# subgraph cluster_workflow_box_inner { label=""; penwidth=0
#
# /* Style for nodes representing atomic programs in workflow */
# node[shape=box style=filled fillcolor="#CCFFCC" peripheries=1 fontname=Helvetica]
#
# /* Nodes representing atomic programs in workflow */
#
#         "1_p1" [shape=record rankdir=LR label="{<f0> step 1 (p1) }"];
#
#         "2_p1" [shape=record rankdir=LR label="{<f0> step 2 (p1) }"];
#
#         "2_p5" [shape=record rankdir=LR label="{<f0> step 2 (p5) }"];
#
#         "3_p6" [shape=record rankdir=LR label="{<f0> step 3 (p6) }"];
#
#         "4_p4" [shape=record rankdir=LR label="{<f0> step 4 (p4) }"];
#
#         "5_p8" [shape=record rankdir=LR label="{<f0> step 5 (p8) }"];
#
# /* Style for nodes representing non-parameter data channels in workflow */
# node[shape=box style="rounded,filled" fillcolor="#FFFFCC" peripheries=1 fontname=Helvetica]
#
# /* Nodes for non-parameter data channels in workflow */
#
#         "column_state(c1,1)" [shape=record rankdir=LR label="{<f0> column_state(c1,1) }"]
#
#         "column_state(c1,2)" [shape=record rankdir=LR label="{<f0> column_state(c1,2) }"]
#
#         "column_state(c2,1)" [shape=record rankdir=LR label="{<f0> column_state(c2,1) }"]
#
#         "column_state(c3,1)" [shape=record rankdir=LR label="{<f0> column_state(c3,1) }"]
#
#         "column_state(c2,t2_1)" [shape=record rankdir=LR label="{<f0> column_state(c2,t2_1) }"]
#
#         "column_state(c2,t2_2)" [shape=record rankdir=LR label="{<f0> column_state(c2,t2_2) }"]
#
#         "column_state(c2,t2_3)" [shape=record rankdir=LR label="{<f0> column_state(c2,t2_3) }"]
#
#         "column_state(c3,2)" [shape=record rankdir=LR label="{<f0> column_state(c3,2) }"]
#
#         "column_state(c2,t2_4)" [shape=record rankdir=LR label="{<f0> column_state(c2,t2_4) }"]
#
#         "column_state(c5,1)" [shape=record rankdir=LR label="{<f0> column_state(c5,1) }"]
#
#         "column_state(c3,3)" [shape=record rankdir=LR label="{<f0> column_state(c3,3) }"]
#
# /* Style for nodes representing parameter channels in workflow */
# node[shape=box style="rounded,filled" fillcolor="#FCFCFC" peripheries=1 fontname=Helvetica]
#
# /* Nodes representing parameter channels in workflow */
#
# node[shape=box style=filled fillcolor="#CCCCFF" peripheries=1 fontname=Helvetica]
#
# node[shape=box style="rounded,filled" fillcolor="#CCFFFF" peripheries=1 fontname=Helvetica]
#
# node[shape=box style="rounded,filled" fillcolor="#FFDDDD" peripheries=1 fontname=Helvetica]
#
# node[shape=box style=filled fillcolor="#CCFFFF" peripheries=1 fontname=Helvetica]
#
# /* Edges representing connections between programs and channels */
#
#             "column_state(c1,1)" -> "1_p1" [label="" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#             "1_p1" -> "column_state(c1,2)" [label="" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#             "1_p1" -> "column_state(c2,1)" [label="" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#             "1_p1" -> "column_state(c3,1)" [label="" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#             "column_state(c2,1)" -> "2_p1" [label="" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#             "2_p1" -> "column_state(c2,t2_1)" [label="" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#             "column_state(c2,1)" -> "2_p5" [label="" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#             "2_p5" -> "column_state(c2,t2_2)" [label="" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#             "column_state(c2,t2_2)" -> "3_p6" [label="" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#             "3_p6" -> "column_state(c2,t2_3)" [label="" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#             "column_state(c3,1)" -> "4_p4" [label="" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#             "4_p4" -> "column_state(c3,2)" [label="" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#             "column_state(c2,t2_2)" -> "4_p4" [label="" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#             "4_p4" -> "column_state(c2,t2_4)" [label="" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#             "4_p4" -> "column_state(c5,1)" [label="" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#             "column_state(c3,2)" -> "5_p8" [label="" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#             "5_p8" -> "column_state(c3,3)" [label="" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
# /* End of double cluster for drawing box around nodes in workflow */
# }}
#
# /* End of top-level graph */
# }

# %%
generate_pdf(gv_string,"workflow_step")

# %%
# visualize using graphviz yw layout

nodes_def = """
digraph "[stackcollapse]" {
node [style=filled fillcolor="#f8f8f8"]
"""

edge_def = ""

# workflow template gv format

header = """
/* Start of top-level graph */
digraph Workflow {
rankdir=TB

/* Start of double cluster for drawing box around nodes in workflow */
subgraph cluster_workflow_box_outer { label=""; penwidth=0
subgraph cluster_workflow_box_inner { label=""; penwidth=0
"""

single_process = """
/* Style for nodes representing atomic programs in workflow */
node[shape=box style=filled fillcolor="#CCFFCC" peripheries=1 fontname=Helvetica]

/* Nodes representing atomic programs in workflow */
"""
#state_4 [shape=record rankdir=LR label="{<f0> step 4 (to_date) | grel\:value.replace(/\\/i,'') | 16492 cells changed}"];


side_b_process = """
node[shape=box style=filled fillcolor="#CCCCFF" peripheries=1 fontname=Helvetica]
"""
#state_5 [shape=record rankdir=LR label="{<f0> state_5 |<f1> core/mass-edit\nclustering\ngroup clustering 4 processes}"];

side_b_data = """
node[shape=box style="rounded,filled" fillcolor="#FFDDDD" peripheries=1 fontname=Helvetica]
"""

side_a_data = """
node[shape=box style="rounded,filled" fillcolor="#CCFFFF" peripheries=1 fontname=Helvetica]
"""


freq_pattern_nodes = """
node[shape=box style=filled fillcolor="#CCFFFF" peripheries=1 fontname=Helvetica]
"""
#state_5 [shape=record rankdir=LR label="{<f0> state_5 |<f1> core/mass-edit\nclustering\ngroup clustering 4 processes}"];

column_nodes = """
/* Style for nodes representing non-parameter data channels in workflow */
node[shape=box style="rounded,filled" fillcolor="#FFFFCC" peripheries=1 fontname=Helvetica]

/* Nodes for non-parameter data channels in workflow */
"""
#"col12_0-date" [shape=record rankdir=LR label="{<f0> date_0 }"]

column_schema_nodes = """
/* Style for nodes representing non-parameter data channels in workflow */
node[shape=box style="rounded,filled,dashed" fillcolor="#FFFFCC" peripheries=1 fontname=Helvetica]
"""

parameters_nodes = """
/* Style for nodes representing parameter channels in workflow */
node[shape=box style="rounded,filled,dashed" fillcolor="#FCFCFC" peripheries=1 fontname=Helvetica]

/* Nodes representing parameter channels in workflow */
"""

edges = """
/* Edges representing connections between programs and channels */
"""
#"col12_0-date" -> state_4


footer = """
/* End of double cluster for drawing box around nodes in workflow */
}}

/* End of top-level graph */
}
"""

# process nodes
for p in df_output_str[("process",2)]:
    freq_pattern_nodes+='''
    "{pid}" [shape=record rankdir=LR label="{{<f0> {pid} ({process_name}) }}"];
    '''.format(pid=p[1],process_name=p[2])

# schema nodes
for cs in df_output_str[("column_schema",3)]:    
    column_schema_nodes+="""
    "{node_name}" [shape=record rankdir=LR label="{{<f0> {label} }}"]
    """.format(node_name=cs[1],label=cs[1])
    parameters_nodes+="""
    "{node_name}" [shape=record rankdir=LR label="{{<f0> {label} }}"]
    """.format(node_name=cs[1]+"_"+cs[2],label=cs[3])
    edges+="""
        {input} -> {output} [label="{data}" weight=14 color="#b26e37" tooltip="" labeltooltip=""]    
    """.format(input=cs[1],output=cs[1]+"_"+cs[2],data=cs[2])   

# edge input output
for inp in df_output_str[("input_process",3)]:                    
    edges+="""
        {input} -> {output} [label="{data}" weight=14 color="#b26e37" tooltip="" labeltooltip=""]    
    """.format(input=inp[3],output=inp[1],data="")            

for out in df_output_str[("output_process",3)]:                    
    edges+="""
        {input} -> {output} [label="{data}" weight=14 color="#b26e37" tooltip="" labeltooltip=""]    
    """.format(input=out[1],output=out[3],data="")            


node_col = set()
node_step = set()
node_edges = set()

cl_sc_map = {}
for cl in df_output_str[("column",4)]:
    cl_sc_map[cl[1]] = cl[3]

for s,fn in zip(df_output_str[("workflow_step",4)],df_output[("workflow_step",4)]):
    if s[2] not in node_col:
        column_nodes+="""
        "{node_name}" [shape=record rankdir=LR label="{{<f0> {label} }}"]
        """.format(node_name=s[2],label=s[2])
        node_col.add(s[2])
        
        #print(fn.)
        edges+="""
            "{input}" -> "{output}" [label="{data}" weight=14 color="#b26e37" tooltip="" labeltooltip="" style="dashed"]    
        """.format(input=s[2],output=cl_sc_map[fn.arguments[1].arguments[0].name],data="associatedWith")
        node_edges.add(s[2]+"_"+cl_sc_map[fn.arguments[1].arguments[0].name])
        
    if s[4] not in node_col:
        column_nodes+="""
        "{node_name}" [shape=record rankdir=LR label="{{<f0> {label} }}"]
        """.format(node_name=s[4],label=s[4])
        node_col.add(s[4])
        
        edges+="""
            "{input}" -> "{output}" [label="{data}" weight=14 color="#b26e37" tooltip="" labeltooltip="" style="dashed"]    
        """.format(input=s[4],output=cl_sc_map[fn.arguments[3].arguments[0].name],data="associatedWith")
        node_edges.add(s[4]+"_"+cl_sc_map[fn.arguments[3].arguments[0].name])
        
    if s[1]+"_"+s[3] not in node_step:
        single_process+='''
        "{pid}" [shape=record rankdir=LR label="{{<f0> step {step_id} ({process_name}) }}"];
        '''.format(pid=s[1]+"_"+s[3],step_id=s[1],process_name=s[3])
        node_step.add(s[1]+"_"+s[3])
        
        edges+="""
        "{input}" -> "{output}" [label="{data}" weight=14 color="#b26e37" tooltip="" labeltooltip="" style="dashed"]    
        """.format(input=s[1]+"_"+s[3],output=s[3],data="associatedWith")
        node_edges.add(s[1]+"_"+s[3]+"_"+s[3])
    
    if s[2]+"_"+s[1]+"_"+s[3] not in node_edges:
        edges+="""
            "{input}" -> "{output}" [label="{data}" weight=14 color="#b26e37" tooltip="" labeltooltip=""]    
        """.format(input=s[2],output=s[1]+"_"+s[3],data="")
        node_edges.add(s[2]+"_"+s[1]+"_"+s[3])
    
    if s[1]+"_"+s[3]+"_"+s[4] not in node_edges:
        edges+="""
            "{input}" -> "{output}" [label="{data}" weight=14 color="#b26e37" tooltip="" labeltooltip=""]    
        """.format(input=s[1]+"_"+s[3],output=s[4],data="") 
        node_edges.add(s[1]+"_"+s[3]+"_"+s[4])
            
            
            
gv_string = header+single_process+column_nodes+parameters_nodes+side_b_process+side_a_data+side_b_data+freq_pattern_nodes+edges+footer

# %%
fn.arguments[1].arguments[0].name
# Out:
# 'c3'

# %%
generate_pdf(gv_string,"workflow_step")

# %%
# visualize using graphviz yw layout

nodes_def = """
digraph "[stackcollapse]" {
node [style=filled fillcolor="#f8f8f8"]
"""

edge_def = ""

# workflow template gv format

header = """
/* Start of top-level graph */
digraph Workflow {
rankdir=TB

"""

sub_graph_workflow_step = """
subgraph cluster_0 { label="workflow_step"; color="blue";
"""

end_sub_graph_workflow_step = """
}
"""

sub_graph_process = """
subgraph cluster_1 { label="process_signature"; color="gray";
"""

end_sub_graph_process = """
}
"""

single_process = """
/* Style for nodes representing atomic programs in workflow */
node[shape=box style=filled fillcolor="#CCFFCC" peripheries=1 fontname=Helvetica]

/* Nodes representing atomic programs in workflow */
"""
#state_4 [shape=record rankdir=LR label="{<f0> step 4 (to_date) | grel\:value.replace(/\\/i,'') | 16492 cells changed}"];


side_b_process = """
node[shape=box style=filled fillcolor="#CCCCFF" peripheries=1 fontname=Helvetica]
"""
#state_5 [shape=record rankdir=LR label="{<f0> state_5 |<f1> core/mass-edit\nclustering\ngroup clustering 4 processes}"];

side_b_data = """
node[shape=box style="rounded,filled" fillcolor="#FFDDDD" peripheries=1 fontname=Helvetica]
"""

side_a_data = """
node[shape=box style="rounded,filled" fillcolor="#CCFFFF" peripheries=1 fontname=Helvetica]
"""


freq_pattern_nodes = """
node[shape=box style=filled fillcolor="#CCFFFF" peripheries=1 fontname=Helvetica]
"""
#state_5 [shape=record rankdir=LR label="{<f0> state_5 |<f1> core/mass-edit\nclustering\ngroup clustering 4 processes}"];

column_nodes = """
/* Style for nodes representing non-parameter data channels in workflow */
node[shape=box style="rounded,filled" fillcolor="#FFFFCC" peripheries=1 fontname=Helvetica]

/* Nodes for non-parameter data channels in workflow */
"""
#"col12_0-date" [shape=record rankdir=LR label="{<f0> date_0 }"]

column_schema_nodes = """
/* Style for nodes representing non-parameter data channels in workflow */
node[shape=box style="rounded,filled,dashed" fillcolor="#FFFFCC" peripheries=1 fontname=Helvetica]
"""

parameters_nodes = """
/* Style for nodes representing parameter channels in workflow */
node[shape=box style="rounded,filled,dashed" fillcolor="#FCFCFC" peripheries=1 fontname=Helvetica]

/* Nodes representing parameter channels in workflow */
"""

edges = """
/* Edges representing connections between programs and channels */
"""
#"col12_0-date" -> state_4


footer = """

/* End of top-level graph */
}
"""

# process nodes
for p in df_output_str[("process",2)]:
    freq_pattern_nodes+='''
    "{pid}" [shape=record rankdir=LR label="{{<f0> {pid} ({process_name}) }}"];
    '''.format(pid=p[1],process_name=p[2])

# schema nodes
for cs in df_output_str[("column_schema",3)]:    
    column_schema_nodes+="""
    "{node_name}" [shape=record rankdir=LR label="{{<f0> {label} }}"]
    """.format(node_name=cs[1],label=cs[1])
    parameters_nodes+="""
    "{node_name}" [shape=record rankdir=LR label="{{<f0> {label} }}"]
    """.format(node_name=cs[1]+"_"+cs[2],label=cs[3])
    edges+="""
        {input} -> {output} [label="{data}" weight=14 color="#b26e37" tooltip="" labeltooltip=""]    
    """.format(input=cs[1],output=cs[1]+"_"+cs[2],data=cs[2])   

# edge input output
for inp in df_output_str[("input_process",3)]:                    
    edges+="""
        {input} -> {output} [label="{data}" weight=14 color="#b26e37" tooltip="" labeltooltip=""]    
    """.format(input=inp[3],output=inp[1],data="")            

for out in df_output_str[("output_process",3)]:                    
    edges+="""
        {input} -> {output} [label="{data}" weight=14 color="#b26e37" tooltip="" labeltooltip=""]    
    """.format(input=out[1],output=out[3],data="")            


node_col = set()
node_step = set()
node_edges = set()

cl_sc_map = {}
for cl in df_output_str[("column",4)]:
    cl_sc_map[cl[1]] = cl[3]

for s,fn in zip(df_output_str[("workflow_step",4)],df_output[("workflow_step",4)]):
    if s[2] not in node_col:
        column_nodes+="""
        "{node_name}" [shape=record rankdir=LR label="{{<f0> {label} }}"]
        """.format(node_name=s[2],label=s[2])
        node_col.add(s[2])
        
        #print(fn.)
        edges+="""
            "{input}" -> "{output}" [label="{data}" weight=14 color="#b26e37" tooltip="" labeltooltip="" style="dashed"]    
        """.format(input=s[2],output=cl_sc_map[fn.arguments[1].arguments[0].name],data="associatedWith")
        node_edges.add(s[2]+"_"+cl_sc_map[fn.arguments[1].arguments[0].name])
        
    if s[4] not in node_col:
        column_nodes+="""
        "{node_name}" [shape=record rankdir=LR label="{{<f0> {label} }}"]
        """.format(node_name=s[4],label=s[4])
        node_col.add(s[4])
        
        edges+="""
            "{input}" -> "{output}" [label="{data}" weight=14 color="#b26e37" tooltip="" labeltooltip="" style="dashed"]    
        """.format(input=s[4],output=cl_sc_map[fn.arguments[3].arguments[0].name],data="associatedWith")
        node_edges.add(s[4]+"_"+cl_sc_map[fn.arguments[3].arguments[0].name])
        
    if s[1]+"_"+s[3] not in node_step:
        single_process+='''
        "{pid}" [shape=record rankdir=LR label="{{<f0> step {step_id} ({process_name}) }}"];
        '''.format(pid=s[1]+"_"+s[3],step_id=s[1],process_name=s[3])
        node_step.add(s[1]+"_"+s[3])
        
        edges+="""
        "{input}" -> "{output}" [label="{data}" weight=14 color="#b26e37" tooltip="" labeltooltip="" style="dashed"]    
        """.format(input=s[1]+"_"+s[3],output=s[3],data="associatedWith")
        node_edges.add(s[1]+"_"+s[3]+"_"+s[3])
    
    if s[2]+"_"+s[1]+"_"+s[3] not in node_edges:
        edges+="""
            "{input}" -> "{output}" [label="{data}" weight=14 color="#b26e37" tooltip="" labeltooltip=""]    
        """.format(input=s[2],output=s[1]+"_"+s[3],data="")
        node_edges.add(s[2]+"_"+s[1]+"_"+s[3])
    
    if s[1]+"_"+s[3]+"_"+s[4] not in node_edges:
        edges+="""
            "{input}" -> "{output}" [label="{data}" weight=14 color="#b26e37" tooltip="" labeltooltip=""]    
        """.format(input=s[1]+"_"+s[3],output=s[4],data="") 
        node_edges.add(s[1]+"_"+s[3]+"_"+s[4])
            
            
            
#gv_string = header+single_process+column_nodes+parameters_nodes+side_b_process+side_a_data+side_b_data+freq_pattern_nodes+edges+footer

gv_string = header+sub_graph_workflow_step+single_process+column_nodes+end_sub_graph_workflow_step+sub_graph_process+parameters_nodes+side_b_process+side_a_data+side_b_data+column_schema_nodes+freq_pattern_nodes+end_sub_graph_process+edges+footer

# %%
print(gv_string)
# Out:
# /* Start of top-level graph */
# digraph Workflow {
# rankdir=TB
#
#
# subgraph cluster_0 { label="workflow_step"; color="blue";
#
# /* Style for nodes representing atomic programs in workflow */
# node[shape=box style=filled fillcolor="#CCFFCC" peripheries=1 fontname=Helvetica]
#
# /* Nodes representing atomic programs in workflow */
#
#         "1_p1" [shape=record rankdir=LR label="{<f0> step 1 (p1) }"];
#
#         "2_p1" [shape=record rankdir=LR label="{<f0> step 2 (p1) }"];
#
#         "2_p5" [shape=record rankdir=LR label="{<f0> step 2 (p5) }"];
#
#         "3_p6" [shape=record rankdir=LR label="{<f0> step 3 (p6) }"];
#
#         "4_p4" [shape=record rankdir=LR label="{<f0> step 4 (p4) }"];
#
#         "5_p8" [shape=record rankdir=LR label="{<f0> step 5 (p8) }"];
#
# /* Style for nodes representing non-parameter data channels in workflow */
# node[shape=box style="rounded,filled" fillcolor="#FFFFCC" peripheries=1 fontname=Helvetica]
#
# /* Nodes for non-parameter data channels in workflow */
#
#         "column_state(c1,1)" [shape=record rankdir=LR label="{<f0> column_state(c1,1) }"]
#
#         "column_state(c1,2)" [shape=record rankdir=LR label="{<f0> column_state(c1,2) }"]
#
#         "column_state(c2,1)" [shape=record rankdir=LR label="{<f0> column_state(c2,1) }"]
#
#         "column_state(c3,1)" [shape=record rankdir=LR label="{<f0> column_state(c3,1) }"]
#
#         "column_state(c2,t2_1)" [shape=record rankdir=LR label="{<f0> column_state(c2,t2_1) }"]
#
#         "column_state(c2,t2_2)" [shape=record rankdir=LR label="{<f0> column_state(c2,t2_2) }"]
#
#         "column_state(c2,t2_3)" [shape=record rankdir=LR label="{<f0> column_state(c2,t2_3) }"]
#
#         "column_state(c3,2)" [shape=record rankdir=LR label="{<f0> column_state(c3,2) }"]
#
#         "column_state(c2,t2_4)" [shape=record rankdir=LR label="{<f0> column_state(c2,t2_4) }"]
#
#         "column_state(c5,1)" [shape=record rankdir=LR label="{<f0> column_state(c5,1) }"]
#
#         "column_state(c3,3)" [shape=record rankdir=LR label="{<f0> column_state(c3,3) }"]
#
# }
#
# subgraph cluster_1 { label="process_signature"; color="gray";
#
# /* Style for nodes representing parameter channels in workflow */
# node[shape=box style="rounded,filled,dashed" fillcolor="#FCFCFC" peripheries=1 fontname=Helvetica]
#
# /* Nodes representing parameter channels in workflow */
#
#     "cs1_name" [shape=record rankdir=LR label="{<f0> full_name }"]
#
#     "cs1_data_type" [shape=record rankdir=LR label="{<f0> text }"]
#
#     "cs2_name" [shape=record rankdir=LR label="{<f0> first_name }"]
#
#     "cs2_data_type" [shape=record rankdir=LR label="{<f0> text }"]
#
#     "cs3_name" [shape=record rankdir=LR label="{<f0> last_name }"]
#
#     "cs3_data_type" [shape=record rankdir=LR label="{<f0> text }"]
#
#     "cs4_name" [shape=record rankdir=LR label="{<f0> date }"]
#
#     "cs4_data_type" [shape=record rankdir=LR label="{<f0> text }"]
#
#     "cs5_data_type" [shape=record rankdir=LR label="{<f0> text }"]
#
#     "cs6_name" [shape=record rankdir=LR label="{<f0> ssn }"]
#
#     "cs6_data_type" [shape=record rankdir=LR label="{<f0> text }"]
#
#     "cs7_name" [shape=record rankdir=LR label="{<f0> ssn }"]
#
#     "cs7_data_type" [shape=record rankdir=LR label="{<f0> number }"]
#
#     "cs8_data_type" [shape=record rankdir=LR label="{<f0> number }"]
#
# node[shape=box style=filled fillcolor="#CCCCFF" peripheries=1 fontname=Helvetica]
#
# node[shape=box style="rounded,filled" fillcolor="#CCFFFF" peripheries=1 fontname=Helvetica]
#
# node[shape=box style="rounded,filled" fillcolor="#FFDDDD" peripheries=1 fontname=Helvetica]
#
# /* Style for nodes representing non-parameter data channels in workflow */
# node[shape=box style="rounded,filled,dashed" fillcolor="#FFFFCC" peripheries=1 fontname=Helvetica]
#
#     "cs1" [shape=record rankdir=LR label="{<f0> cs1 }"]
#
#     "cs1" [shape=record rankdir=LR label="{<f0> cs1 }"]
#
#     "cs2" [shape=record rankdir=LR label="{<f0> cs2 }"]
#
#     "cs2" [shape=record rankdir=LR label="{<f0> cs2 }"]
#
#     "cs3" [shape=record rankdir=LR label="{<f0> cs3 }"]
#
#     "cs3" [shape=record rankdir=LR label="{<f0> cs3 }"]
#
#     "cs4" [shape=record rankdir=LR label="{<f0> cs4 }"]
#
#     "cs4" [shape=record rankdir=LR label="{<f0> cs4 }"]
#
#     "cs5" [shape=record rankdir=LR label="{<f0> cs5 }"]
#
#     "cs6" [shape=record rankdir=LR label="{<f0> cs6 }"]
#
#     "cs6" [shape=record rankdir=LR label="{<f0> cs6 }"]
#
#     "cs7" [shape=record rankdir=LR label="{<f0> cs7 }"]
#
#     "cs7" [shape=record rankdir=LR label="{<f0> cs7 }"]
#
#     "cs8" [shape=record rankdir=LR label="{<f0> cs8 }"]
#
# node[shape=box style=filled fillcolor="#CCFFFF" peripheries=1 fontname=Helvetica]
#
#     "p1" [shape=record rankdir=LR label="{<f0> p1 (split_name) }"];
#
#     "p2" [shape=record rankdir=LR label="{<f0> p2 (upper_case) }"];
#
#     "p3" [shape=record rankdir=LR label="{<f0> p3 (rename_col) }"];
#
#     "p4" [shape=record rankdir=LR label="{<f0> p4 (merge_col) }"];
#
#     "p5" [shape=record rankdir=LR label="{<f0> p5 (normalize_char) }"];
#
#     "p6" [shape=record rankdir=LR label="{<f0> p6 (normalize_date) }"];
#
#     "p7" [shape=record rankdir=LR label="{<f0> p7 (fixed_ssn) }"];
#
#     "p8" [shape=record rankdir=LR label="{<f0> p8 (lower_case) }"];
#
# }
#
# /* Edges representing connections between programs and channels */
#
#         cs1 -> cs1_name [label="name" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#         cs1 -> cs1_data_type [label="data_type" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#         cs2 -> cs2_name [label="name" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#         cs2 -> cs2_data_type [label="data_type" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#         cs3 -> cs3_name [label="name" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#         cs3 -> cs3_data_type [label="data_type" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#         cs4 -> cs4_name [label="name" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#         cs4 -> cs4_data_type [label="data_type" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#         cs5 -> cs5_data_type [label="data_type" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#         cs6 -> cs6_name [label="name" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#         cs6 -> cs6_data_type [label="data_type" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#         cs7 -> cs7_name [label="name" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#         cs7 -> cs7_data_type [label="data_type" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#         cs8 -> cs8_data_type [label="data_type" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#         cs1 -> p1 [label="" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#         cs5 -> p2 [label="" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#         cs5 -> p3 [label="" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#         cs2 -> p4 [label="" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#         cs3 -> p4 [label="" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#         cs5 -> p5 [label="" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#         cs4 -> p6 [label="" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#         cs6 -> p7 [label="" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#         cs5 -> p8 [label="" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#         p1 -> cs1 [label="" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#         p1 -> cs2 [label="" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#         p1 -> cs3 [label="" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#         p2 -> cs5 [label="" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#         p3 -> cs5 [label="" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#         p4 -> cs5 [label="" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#         p5 -> cs5 [label="" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#         p6 -> cs8 [label="" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#         p7 -> cs7 [label="" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#         p8 -> cs5 [label="" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#             "column_state(c1,1)" -> "cs1" [label="associatedWith" weight=14 color="#b26e37" tooltip="" labeltooltip="" style="dashed"]
#
#             "column_state(c1,2)" -> "cs1" [label="associatedWith" weight=14 color="#b26e37" tooltip="" labeltooltip="" style="dashed"]
#
#         "1_p1" -> "p1" [label="associatedWith" weight=14 color="#b26e37" tooltip="" labeltooltip="" style="dashed"]
#
#             "column_state(c1,1)" -> "1_p1" [label="" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#             "1_p1" -> "column_state(c1,2)" [label="" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#             "column_state(c2,1)" -> "cs2" [label="associatedWith" weight=14 color="#b26e37" tooltip="" labeltooltip="" style="dashed"]
#
#             "1_p1" -> "column_state(c2,1)" [label="" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#             "column_state(c3,1)" -> "cs3" [label="associatedWith" weight=14 color="#b26e37" tooltip="" labeltooltip="" style="dashed"]
#
#             "1_p1" -> "column_state(c3,1)" [label="" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#             "column_state(c2,t2_1)" -> "cs2" [label="associatedWith" weight=14 color="#b26e37" tooltip="" labeltooltip="" style="dashed"]
#
#         "2_p1" -> "p1" [label="associatedWith" weight=14 color="#b26e37" tooltip="" labeltooltip="" style="dashed"]
#
#             "column_state(c2,1)" -> "2_p1" [label="" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#             "2_p1" -> "column_state(c2,t2_1)" [label="" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#             "column_state(c2,t2_2)" -> "cs2" [label="associatedWith" weight=14 color="#b26e37" tooltip="" labeltooltip="" style="dashed"]
#
#         "2_p5" -> "p5" [label="associatedWith" weight=14 color="#b26e37" tooltip="" labeltooltip="" style="dashed"]
#
#             "column_state(c2,1)" -> "2_p5" [label="" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#             "2_p5" -> "column_state(c2,t2_2)" [label="" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#             "column_state(c2,t2_3)" -> "cs2" [label="associatedWith" weight=14 color="#b26e37" tooltip="" labeltooltip="" style="dashed"]
#
#         "3_p6" -> "p6" [label="associatedWith" weight=14 color="#b26e37" tooltip="" labeltooltip="" style="dashed"]
#
#             "column_state(c2,t2_2)" -> "3_p6" [label="" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#             "3_p6" -> "column_state(c2,t2_3)" [label="" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#             "column_state(c3,2)" -> "cs3" [label="associatedWith" weight=14 color="#b26e37" tooltip="" labeltooltip="" style="dashed"]
#
#         "4_p4" -> "p4" [label="associatedWith" weight=14 color="#b26e37" tooltip="" labeltooltip="" style="dashed"]
#
#             "column_state(c3,1)" -> "4_p4" [label="" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#             "4_p4" -> "column_state(c3,2)" [label="" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#             "column_state(c2,t2_4)" -> "cs2" [label="associatedWith" weight=14 color="#b26e37" tooltip="" labeltooltip="" style="dashed"]
#
#             "column_state(c2,t2_2)" -> "4_p4" [label="" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#             "4_p4" -> "column_state(c2,t2_4)" [label="" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#             "column_state(c5,1)" -> "cs5" [label="associatedWith" weight=14 color="#b26e37" tooltip="" labeltooltip="" style="dashed"]
#
#             "4_p4" -> "column_state(c5,1)" [label="" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#             "column_state(c3,3)" -> "cs3" [label="associatedWith" weight=14 color="#b26e37" tooltip="" labeltooltip="" style="dashed"]
#
#         "5_p8" -> "p8" [label="associatedWith" weight=14 color="#b26e37" tooltip="" labeltooltip="" style="dashed"]
#
#             "column_state(c3,2)" -> "5_p8" [label="" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#             "5_p8" -> "column_state(c3,3)" [label="" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#
# /* End of top-level graph */
# }

# %%
generate_pdf(gv_string,"workflow_step_2")

# %%
import pandas as pd
pd.DataFrame(df_output_str[("accumulated_dq_problem",2)])
accumulated_dq = {}
for p,fp in zip(df_output_str[("accumulated_dq_problem",2)],df_output[("accumulated_dq_problem",2)]):
    #pp = [str(x) for x in fp.arguments[0].arguments]
    try:
        accumulated_dq[p[1]]
    except:
        accumulated_dq[p[1]] = []
    accumulated_dq[p[1]].append(p[2])

# %%
pd.DataFrame(df_output_str[("process",2)])
# Out:
#          0   1               2
# 0  process  p1      split_name
# 1  process  p2      upper_case
# 2  process  p3      rename_col
# 3  process  p4       merge_col
# 4  process  p5  normalize_char
# 5  process  p6  normalize_date
# 6  process  p7       fixed_ssn
# 7  process  p8      lower_case

# %%
accumulated_dq
# Out:
# {'column_state(c1,2)': ['unknown_char'],
#  'column_state(c2,1)': ['unknown_char', 'lower_case'],
#  'column_state(c3,1)': ['lower_case'],
#  'column_state(c2,t2_1)': ['unknown_char', 'lower_case'],
#  'column_state(c2,t2_2)': ['lower_case'],
#  'column_state(c2,t2_3)': ['lower_case'],
#  'column_state(c3,2)': ['lower_case'],
#  'column_state(c2,t2_4)': ['lower_case'],
#  'column_state(c1,1)': ['null_value', 'split_name', 'unknown_char']}

# %%
import pandas as pd
workflow_input_violation = {}
for p,fp in zip(df_output_str[("workflow_input_violation",4)],df_output[("workflow_input_violation",4)]):
    if p[2] == "unexpected":
        #workflow_input_violation[(p[1],p[4])] = [x.name for x in fp.arguments[2].arguments]
        #workflow_input_violation[(p[4],p[1],p[3])] = (p[4],p[1],p[3])
        pass
    if p[2] == "missing":
        workflow_input_violation[(p[1],p[3])] = [x.name for x in fp.arguments[3].arguments]

# %%
import pandas as pd
workflow_output_violation = {}
for p,fp in zip(df_output_str[("workflow_output_violation",4)],df_output[("workflow_output_violation",4)]):
    if p[2] == "unexpected":
        #workflow_input_violation[(p[1],p[4])] = [x.name for x in fp.arguments[2].arguments]
        #workflow_input_violation[(p[4],p[1],p[3])] = (p[4],p[1],p[3])
        pass
    if p[2] == "missing":
        workflow_output_violation[(p[1],p[3])] = [x.name for x in fp.arguments[3].arguments]

# %%
process_name = {}
for p in df_output_str[("process",2)]:
    process_name[p[1]] = p[2]

# %%
column_schema = {}
for p in df_output_str[("column",4)]:
    column_schema[p[1]] = p[3]

# %%
workflow_input_violation
# Out:
# {('2', 'p1'): ['cs1', 'name', 'full_name'],
#  ('3', 'p6'): ['cs4', 'name', 'date']}

# %%
workflow_output_violation
# Out:
# {('2', 'p1'): ['cs3', 'name', 'last_name'],
#  ('3', 'p6'): ['cs8', 'data_type', 'number']}

# %%
# visualize using graphviz yw layout

nodes_def = """
digraph "[stackcollapse]" {
node [style=filled fillcolor="#f8f8f8"]
"""

edge_def = ""

# workflow template gv format

header = """
/* Start of top-level graph */
digraph Workflow {
rankdir=TB

"""

sub_graph_workflow_step = """
subgraph cluster_0 { label="workflow_step"; color="green";
"""

end_sub_graph_workflow_step = """
}
"""

sub_graph_process = """
subgraph cluster_1 { label="process_signature"; color="blue";
"""

end_sub_graph_process = """
}
"""

single_process = """
/* Style for nodes representing atomic programs in workflow */
node[shape=box style=filled fillcolor="#CCFFCC" peripheries=1 fontname=Helvetica]

/* Nodes representing atomic programs in workflow */
"""
#state_4 [shape=record rankdir=LR label="{<f0> step 4 (to_date) | grel\:value.replace(/\\/i,'') | 16492 cells changed}"];

process_violation = """
/* Style for violation of process because of missing parameter  */
node[shape=box style=filled fillcolor="#FFCCCC" peripheries=1 fontname=Helvetica]

/* Nodes representing atomic programs in workflow */
"""


side_b_process = """
node[shape=box style=filled fillcolor="#CCCCFF" peripheries=1 fontname=Helvetica]
"""
#state_5 [shape=record rankdir=LR label="{<f0> state_5 |<f1> core/mass-edit\nclustering\ngroup clustering 4 processes}"];

side_b_data = """
node[shape=box style="rounded,filled" fillcolor="#FFDDDD" peripheries=1 fontname=Helvetica]
"""

side_a_data = """
node[shape=box style="rounded,filled" fillcolor="#CCFFFF" peripheries=1 fontname=Helvetica]
"""


freq_pattern_nodes = """
node[shape=box style=filled fillcolor="#CCFFFF" peripheries=1 fontname=Helvetica]
"""
#state_5 [shape=record rankdir=LR label="{<f0> state_5 |<f1> core/mass-edit\nclustering\ngroup clustering 4 processes}"];

column_nodes = """
/* Style for nodes representing non-parameter data channels in workflow */
node[shape=box style="rounded,filled" fillcolor="#FFFFCC" peripheries=1 fontname=Helvetica]

/* Nodes for non-parameter data channels in workflow */
"""
#"col12_0-date" [shape=record rankdir=LR label="{<f0> date_0 }"]

column_schema_nodes = """
/* Style for nodes representing non-parameter data channels in workflow */
node[shape=box style="rounded,filled,dashed" fillcolor="#FFFFCC" peripheries=1 fontname=Helvetica]
"""

parameters_nodes = """
/* Style for nodes representing parameter channels in workflow */
node[shape=box style="rounded,filled,dashed" fillcolor="#FCFCFC" peripheries=1 fontname=Helvetica]

/* Nodes representing parameter channels in workflow */
"""

parameters_dqproblem = """
/* Style for nodes representing parameter channels in workflow */
node[shape=box style="rounded,filled,dashed" fillcolor="#FCFCFC" peripheries=1 fontname=Helvetica]

/* Nodes representing parameter channels in workflow */
"""


edges = """
/* Edges representing connections between programs and channels */
"""
#"col12_0-date" -> state_4


footer = """

/* End of top-level graph */
}
"""

# process nodes
for p in df_output_str[("process",2)]:
    freq_pattern_nodes+='''
    "{pid}" [shape=record rankdir=LR label="{{<f0> {pid} ({process_name}) }}"];
    '''.format(pid=p[1],process_name=p[2])

# schema nodes
for cs in df_output_str[("column_schema",3)]:    
    column_schema_nodes+="""
    "{node_name}" [shape=record rankdir=LR label="{{<f0> {label} }}"]
    """.format(node_name=cs[1],label=cs[1])
    parameters_nodes+="""
    "{node_name}" [shape=record rankdir=LR label="{{<f0> {label} }}"]
    """.format(node_name=cs[1]+"_"+cs[2],label=cs[3])
    edges+="""
        {input} -> {output} [label="{data}" weight=14 color="#b26e37" tooltip="" labeltooltip=""]    
    """.format(input=cs[1],output=cs[1]+"_"+cs[2],data=cs[2])   

# edge input output
for inp in df_output_str[("input_process",3)]:                    
    edges+="""
        {input} -> {output} [label="{data}" weight=14 color="#b26e37" tooltip="" labeltooltip=""]    
    """.format(input=inp[3],output=inp[1],data="")            

for out in df_output_str[("output_process",3)]:                    
    edges+="""
        {input} -> {output} [label="{data}" weight=14 color="#b26e37" tooltip="" labeltooltip=""]    
    """.format(input=out[1],output=out[3],data="")            


node_col = set()
node_step = set()
node_edges = set()

cl_sc_map = {}
for cl in df_output_str[("column",4)]:
    cl_sc_map[cl[1]] = cl[3]

for s,fn in zip(df_output_str[("workflow_step",4)],df_output[("workflow_step",4)]):
    if s[2] not in node_col:
        cl = fn.arguments[1].arguments[0].name
        column_nodes+="""
        "{node_name}" [shape=record rankdir=LR label="{{<f0> {label} ({schema}) }}"]
        """.format(node_name=s[2],label=s[2],schema=column_schema[cl])
        node_col.add(s[2])
        
        #print(fn.)
        #edges+="""
        #    "{input}" -> "{output}" [label="{data}" weight=14 color="#b26e37" tooltip="" labeltooltip="" style="dashed"]    
        #""".format(input=s[2],output=cl_sc_map[fn.arguments[1].arguments[0].name],data="associatedWith")
        #node_edges.add(s[2]+"_"+cl_sc_map[fn.arguments[1].arguments[0].name])
        
        # add dq_problem parameter
        if s[2] in accumulated_dq:
            for nn in accumulated_dq[s[2]]:
                #print(nn)
                parameters_dqproblem+="""
                "{node_name}" [shape=record rankdir=LR label="{{<f0> {label} }}"]
                """.format(node_name=s[2]+"_"+nn,label=nn)
                edges+="""
                "{input}" -> "{output}" [label="{data}" weight=14 color="#ccccff" tooltip="" labeltooltip=""]    
                """.format(input=s[2]+"_"+nn,output=s[2],data="dq")
        
        
    if s[4] not in node_col:
        cl = fn.arguments[3].arguments[0].name
        column_nodes+="""
        "{node_name}" [shape=record rankdir=LR label="{{<f0> {label} ({schema}) }}"]
        """.format(node_name=s[4],label=s[4],schema=column_schema[cl])
        node_col.add(s[4])
        
        #edges+="""
        #    "{input}" -> "{output}" [label="{data}" weight=14 color="#b26e37" tooltip="" labeltooltip="" style="dashed"]    
        #""".format(input=s[4],output=cl_sc_map[fn.arguments[3].arguments[0].name],data="associatedWith")
        #node_edges.add(s[4]+"_"+cl_sc_map[fn.arguments[3].arguments[0].name])
        
        if s[4] in accumulated_dq:
            for nn in accumulated_dq[s[4]]:
                #print(nn)
                parameters_dqproblem+="""
                "{node_name}" [shape=record rankdir=LR label="{{<f0> {label} }}"]
                """.format(node_name=s[4]+"_"+nn,label=nn)
                edges+="""
                "{input}" -> "{output}" [label="{data}" weight=14 color="#ccccff" tooltip="" labeltooltip=""]    
                """.format(input=s[4]+"_"+nn,output=s[4],data="dq")
        
        
        
        
    if s[1]+"_"+s[3] not in node_step:
        #print(s[1],s[3]) 
        if (s[1],s[3]) in workflow_input_violation:
            #print("violation")
            process_violation+='''
            "{pid}" [shape=record rankdir=LR label="{{<f0> step {step_id} ({process_name}) }}"];
            '''.format(pid=s[1]+"_"+s[3],step_id=s[1],process_name=s[3]+"-"+process_name[s[3]])
            node_step.add(s[1]+"_"+s[3])
            
            # missing parameter
            missing_param = workflow_input_violation[(s[1],s[3])]
            edges+="""
            "{input}" -> "{output}" [label="{data}" weight=14 color="#ff0000" tooltip="" labeltooltip=""]    
            """.format(output=s[1]+"_"+s[3],input=missing_param[0]+"_"+missing_param[1],data="",color=color)
            node_edges.add(s[1]+"_"+s[3]+"_"+missing_param[0]+"_"+missing_param[1])
        else:
            # get common process name            
            
            single_process+='''
            "{pid}" [shape=record rankdir=LR label="{{<f0> step {step_id} ({process_name}) }}"];
            '''.format(pid=s[1]+"_"+s[3],step_id=s[1],process_name=s[3]+"-"+process_name[s[3]])
            node_step.add(s[1]+"_"+s[3])

        if (s[1],s[3]) in workflow_output_violation:
            # missing parameter
            missing_param = workflow_output_violation[(s[1],s[3])]
            edges+="""
            "{input}" -> "{output}" [label="{data}" weight=14 color="#ff0000" tooltip="" labeltooltip=""]    
            """.format(input=s[1]+"_"+s[3],output=missing_param[0]+"_"+missing_param[1],data="",color=color)
            node_edges.add(s[1]+"_"+s[3]+"_"+missing_param[0]+"_"+missing_param[1])
                                    
        #edges+="""
        #"{input}" -> "{output}" [label="{data}" weight=14 color="#b26e37" tooltip="" labeltooltip="" style="dashed"]    
        #""".format(input=s[1]+"_"+s[3],output=s[3],data="associatedWith")
        #node_edges.add(s[1]+"_"+s[3]+"_"+s[3])
    
    if s[2]+"_"+s[1]+"_"+s[3] not in node_edges:
        # check if it is an input violation error
        #print(s[2],s[3])
        if (s[2],s[1],s[3]) in workflow_input_violation:
            color = "#ff0000"
        else:
            color = "#b26e37"
        
        edges+="""
            "{input}" -> "{output}" [label="{data}" weight=14 color="{color}" tooltip="" labeltooltip=""]    
        """.format(input=s[2],output=s[1]+"_"+s[3],data="",color=color)
        node_edges.add(s[2]+"_"+s[1]+"_"+s[3])
    
    if s[1]+"_"+s[3]+"_"+s[4] not in node_edges:
        edges+="""
            "{input}" -> "{output}" [label="{data}" weight=14 color="#b26e37" tooltip="" labeltooltip=""]    
        """.format(input=s[1]+"_"+s[3],output=s[4],data="") 
        node_edges.add(s[1]+"_"+s[3]+"_"+s[4])
            
            
            
#gv_string = header+single_process+column_nodes+parameters_nodes+side_b_process+side_a_data+side_b_data+freq_pattern_nodes+edges+footer

gv_string = header+sub_graph_workflow_step+ \
    single_process+process_violation+column_nodes+parameters_dqproblem+end_sub_graph_workflow_step+ \
    sub_graph_process+parameters_nodes+side_b_process+side_a_data+side_b_data+ \
    column_schema_nodes+freq_pattern_nodes+end_sub_graph_process+edges+footer

# %%
print(gv_string)
# Out:
# /* Start of top-level graph */
# digraph Workflow {
# rankdir=TB
#
#
# subgraph cluster_0 { label="workflow_step"; color="green";
#
# /* Style for nodes representing atomic programs in workflow */
# node[shape=box style=filled fillcolor="#CCFFCC" peripheries=1 fontname=Helvetica]
#
# /* Nodes representing atomic programs in workflow */
#
#             "1_p1" [shape=record rankdir=LR label="{<f0> step 1 (p1-split_name) }"];
#
#             "2_p5" [shape=record rankdir=LR label="{<f0> step 2 (p5-normalize_char) }"];
#
#             "4_p4" [shape=record rankdir=LR label="{<f0> step 4 (p4-merge_col) }"];
#
#             "5_p8" [shape=record rankdir=LR label="{<f0> step 5 (p8-lower_case) }"];
#
# /* Style for violation of process because of missing parameter  */
# node[shape=box style=filled fillcolor="#FFCCCC" peripheries=1 fontname=Helvetica]
#
# /* Nodes representing atomic programs in workflow */
#
#             "2_p1" [shape=record rankdir=LR label="{<f0> step 2 (p1-split_name) }"];
#
#             "3_p6" [shape=record rankdir=LR label="{<f0> step 3 (p6-normalize_date) }"];
#
# /* Style for nodes representing non-parameter data channels in workflow */
# node[shape=box style="rounded,filled" fillcolor="#FFFFCC" peripheries=1 fontname=Helvetica]
#
# /* Nodes for non-parameter data channels in workflow */
#
#         "column_state(c1,1)" [shape=record rankdir=LR label="{<f0> column_state(c1,1) (cs1) }"]
#
#         "column_state(c1,2)" [shape=record rankdir=LR label="{<f0> column_state(c1,2) (cs1) }"]
#
#         "column_state(c2,1)" [shape=record rankdir=LR label="{<f0> column_state(c2,1) (cs2) }"]
#
#         "column_state(c3,1)" [shape=record rankdir=LR label="{<f0> column_state(c3,1) (cs3) }"]
#
#         "column_state(c2,t2_1)" [shape=record rankdir=LR label="{<f0> column_state(c2,t2_1) (cs2) }"]
#
#         "column_state(c2,t2_2)" [shape=record rankdir=LR label="{<f0> column_state(c2,t2_2) (cs2) }"]
#
#         "column_state(c2,t2_3)" [shape=record rankdir=LR label="{<f0> column_state(c2,t2_3) (cs2) }"]
#
#         "column_state(c3,2)" [shape=record rankdir=LR label="{<f0> column_state(c3,2) (cs3) }"]
#
#         "column_state(c2,t2_4)" [shape=record rankdir=LR label="{<f0> column_state(c2,t2_4) (cs2) }"]
#
#         "column_state(c5,1)" [shape=record rankdir=LR label="{<f0> column_state(c5,1) (cs5) }"]
#
#         "column_state(c3,3)" [shape=record rankdir=LR label="{<f0> column_state(c3,3) (cs3) }"]
#
# /* Style for nodes representing parameter channels in workflow */
# node[shape=box style="rounded,filled,dashed" fillcolor="#FCFCFC" peripheries=1 fontname=Helvetica]
#
# /* Nodes representing parameter channels in workflow */
#
#                 "column_state(c1,1)_null_value" [shape=record rankdir=LR label="{<f0> null_value }"]
#
#                 "column_state(c1,1)_split_name" [shape=record rankdir=LR label="{<f0> split_name }"]
#
#                 "column_state(c1,1)_unknown_char" [shape=record rankdir=LR label="{<f0> unknown_char }"]
#
#                 "column_state(c1,2)_unknown_char" [shape=record rankdir=LR label="{<f0> unknown_char }"]
#
#                 "column_state(c2,1)_unknown_char" [shape=record rankdir=LR label="{<f0> unknown_char }"]
#
#                 "column_state(c2,1)_lower_case" [shape=record rankdir=LR label="{<f0> lower_case }"]
#
#                 "column_state(c3,1)_lower_case" [shape=record rankdir=LR label="{<f0> lower_case }"]
#
#                 "column_state(c2,t2_1)_unknown_char" [shape=record rankdir=LR label="{<f0> unknown_char }"]
#
#                 "column_state(c2,t2_1)_lower_case" [shape=record rankdir=LR label="{<f0> lower_case }"]
#
#                 "column_state(c2,t2_2)_lower_case" [shape=record rankdir=LR label="{<f0> lower_case }"]
#
#                 "column_state(c2,t2_3)_lower_case" [shape=record rankdir=LR label="{<f0> lower_case }"]
#
#                 "column_state(c3,2)_lower_case" [shape=record rankdir=LR label="{<f0> lower_case }"]
#
#                 "column_state(c2,t2_4)_lower_case" [shape=record rankdir=LR label="{<f0> lower_case }"]
#
# }
#
# subgraph cluster_1 { label="process_signature"; color="blue";
#
# /* Style for nodes representing parameter channels in workflow */
# node[shape=box style="rounded,filled,dashed" fillcolor="#FCFCFC" peripheries=1 fontname=Helvetica]
#
# /* Nodes representing parameter channels in workflow */
#
#     "cs1_name" [shape=record rankdir=LR label="{<f0> full_name }"]
#
#     "cs1_data_type" [shape=record rankdir=LR label="{<f0> text }"]
#
#     "cs2_name" [shape=record rankdir=LR label="{<f0> first_name }"]
#
#     "cs2_data_type" [shape=record rankdir=LR label="{<f0> text }"]
#
#     "cs3_name" [shape=record rankdir=LR label="{<f0> last_name }"]
#
#     "cs3_data_type" [shape=record rankdir=LR label="{<f0> text }"]
#
#     "cs4_name" [shape=record rankdir=LR label="{<f0> date }"]
#
#     "cs4_data_type" [shape=record rankdir=LR label="{<f0> text }"]
#
#     "cs5_data_type" [shape=record rankdir=LR label="{<f0> text }"]
#
#     "cs6_name" [shape=record rankdir=LR label="{<f0> ssn }"]
#
#     "cs6_data_type" [shape=record rankdir=LR label="{<f0> text }"]
#
#     "cs7_name" [shape=record rankdir=LR label="{<f0> ssn }"]
#
#     "cs7_data_type" [shape=record rankdir=LR label="{<f0> number }"]
#
#     "cs8_data_type" [shape=record rankdir=LR label="{<f0> number }"]
#
# node[shape=box style=filled fillcolor="#CCCCFF" peripheries=1 fontname=Helvetica]
#
# node[shape=box style="rounded,filled" fillcolor="#CCFFFF" peripheries=1 fontname=Helvetica]
#
# node[shape=box style="rounded,filled" fillcolor="#FFDDDD" peripheries=1 fontname=Helvetica]
#
# /* Style for nodes representing non-parameter data channels in workflow */
# node[shape=box style="rounded,filled,dashed" fillcolor="#FFFFCC" peripheries=1 fontname=Helvetica]
#
#     "cs1" [shape=record rankdir=LR label="{<f0> cs1 }"]
#
#     "cs1" [shape=record rankdir=LR label="{<f0> cs1 }"]
#
#     "cs2" [shape=record rankdir=LR label="{<f0> cs2 }"]
#
#     "cs2" [shape=record rankdir=LR label="{<f0> cs2 }"]
#
#     "cs3" [shape=record rankdir=LR label="{<f0> cs3 }"]
#
#     "cs3" [shape=record rankdir=LR label="{<f0> cs3 }"]
#
#     "cs4" [shape=record rankdir=LR label="{<f0> cs4 }"]
#
#     "cs4" [shape=record rankdir=LR label="{<f0> cs4 }"]
#
#     "cs5" [shape=record rankdir=LR label="{<f0> cs5 }"]
#
#     "cs6" [shape=record rankdir=LR label="{<f0> cs6 }"]
#
#     "cs6" [shape=record rankdir=LR label="{<f0> cs6 }"]
#
#     "cs7" [shape=record rankdir=LR label="{<f0> cs7 }"]
#
#     "cs7" [shape=record rankdir=LR label="{<f0> cs7 }"]
#
#     "cs8" [shape=record rankdir=LR label="{<f0> cs8 }"]
#
# node[shape=box style=filled fillcolor="#CCFFFF" peripheries=1 fontname=Helvetica]
#
#     "p1" [shape=record rankdir=LR label="{<f0> p1 (split_name) }"];
#
#     "p2" [shape=record rankdir=LR label="{<f0> p2 (upper_case) }"];
#
#     "p3" [shape=record rankdir=LR label="{<f0> p3 (rename_col) }"];
#
#     "p4" [shape=record rankdir=LR label="{<f0> p4 (merge_col) }"];
#
#     "p5" [shape=record rankdir=LR label="{<f0> p5 (normalize_char) }"];
#
#     "p6" [shape=record rankdir=LR label="{<f0> p6 (normalize_date) }"];
#
#     "p7" [shape=record rankdir=LR label="{<f0> p7 (fixed_ssn) }"];
#
#     "p8" [shape=record rankdir=LR label="{<f0> p8 (lower_case) }"];
#
# }
#
# /* Edges representing connections between programs and channels */
#
#         cs1 -> cs1_name [label="name" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#         cs1 -> cs1_data_type [label="data_type" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#         cs2 -> cs2_name [label="name" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#         cs2 -> cs2_data_type [label="data_type" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#         cs3 -> cs3_name [label="name" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#         cs3 -> cs3_data_type [label="data_type" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#         cs4 -> cs4_name [label="name" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#         cs4 -> cs4_data_type [label="data_type" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#         cs5 -> cs5_data_type [label="data_type" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#         cs6 -> cs6_name [label="name" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#         cs6 -> cs6_data_type [label="data_type" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#         cs7 -> cs7_name [label="name" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#         cs7 -> cs7_data_type [label="data_type" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#         cs8 -> cs8_data_type [label="data_type" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#         cs1 -> p1 [label="" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#         cs5 -> p2 [label="" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#         cs5 -> p3 [label="" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#         cs2 -> p4 [label="" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#         cs3 -> p4 [label="" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#         cs5 -> p5 [label="" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#         cs4 -> p6 [label="" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#         cs6 -> p7 [label="" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#         cs5 -> p8 [label="" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#         p1 -> cs1 [label="" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#         p1 -> cs2 [label="" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#         p1 -> cs3 [label="" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#         p2 -> cs5 [label="" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#         p3 -> cs5 [label="" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#         p4 -> cs5 [label="" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#         p5 -> cs5 [label="" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#         p6 -> cs8 [label="" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#         p7 -> cs7 [label="" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#         p8 -> cs5 [label="" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#                 "column_state(c1,1)_null_value" -> "column_state(c1,1)" [label="dq" weight=14 color="#ccccff" tooltip="" labeltooltip=""]
#
#                 "column_state(c1,1)_split_name" -> "column_state(c1,1)" [label="dq" weight=14 color="#ccccff" tooltip="" labeltooltip=""]
#
#                 "column_state(c1,1)_unknown_char" -> "column_state(c1,1)" [label="dq" weight=14 color="#ccccff" tooltip="" labeltooltip=""]
#
#                 "column_state(c1,2)_unknown_char" -> "column_state(c1,2)" [label="dq" weight=14 color="#ccccff" tooltip="" labeltooltip=""]
#
#             "column_state(c1,1)" -> "1_p1" [label="" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#             "1_p1" -> "column_state(c1,2)" [label="" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#                 "column_state(c2,1)_unknown_char" -> "column_state(c2,1)" [label="dq" weight=14 color="#ccccff" tooltip="" labeltooltip=""]
#
#                 "column_state(c2,1)_lower_case" -> "column_state(c2,1)" [label="dq" weight=14 color="#ccccff" tooltip="" labeltooltip=""]
#
#             "1_p1" -> "column_state(c2,1)" [label="" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#                 "column_state(c3,1)_lower_case" -> "column_state(c3,1)" [label="dq" weight=14 color="#ccccff" tooltip="" labeltooltip=""]
#
#             "1_p1" -> "column_state(c3,1)" [label="" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#                 "column_state(c2,t2_1)_unknown_char" -> "column_state(c2,t2_1)" [label="dq" weight=14 color="#ccccff" tooltip="" labeltooltip=""]
#
#                 "column_state(c2,t2_1)_lower_case" -> "column_state(c2,t2_1)" [label="dq" weight=14 color="#ccccff" tooltip="" labeltooltip=""]
#
#             "cs1_name" -> "2_p1" [label="" weight=14 color="#ff0000" tooltip="" labeltooltip=""]
#
#             "2_p1" -> "cs3_name" [label="" weight=14 color="#ff0000" tooltip="" labeltooltip=""]
#
#             "column_state(c2,1)" -> "2_p1" [label="" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#             "2_p1" -> "column_state(c2,t2_1)" [label="" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#                 "column_state(c2,t2_2)_lower_case" -> "column_state(c2,t2_2)" [label="dq" weight=14 color="#ccccff" tooltip="" labeltooltip=""]
#
#             "column_state(c2,1)" -> "2_p5" [label="" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#             "2_p5" -> "column_state(c2,t2_2)" [label="" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#                 "column_state(c2,t2_3)_lower_case" -> "column_state(c2,t2_3)" [label="dq" weight=14 color="#ccccff" tooltip="" labeltooltip=""]
#
#             "cs4_name" -> "3_p6" [label="" weight=14 color="#ff0000" tooltip="" labeltooltip=""]
#
#             "3_p6" -> "cs8_data_type" [label="" weight=14 color="#ff0000" tooltip="" labeltooltip=""]
#
#             "column_state(c2,t2_2)" -> "3_p6" [label="" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#             "3_p6" -> "column_state(c2,t2_3)" [label="" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#                 "column_state(c3,2)_lower_case" -> "column_state(c3,2)" [label="dq" weight=14 color="#ccccff" tooltip="" labeltooltip=""]
#
#             "column_state(c3,1)" -> "4_p4" [label="" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#             "4_p4" -> "column_state(c3,2)" [label="" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#                 "column_state(c2,t2_4)_lower_case" -> "column_state(c2,t2_4)" [label="dq" weight=14 color="#ccccff" tooltip="" labeltooltip=""]
#
#             "column_state(c2,t2_2)" -> "4_p4" [label="" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#             "4_p4" -> "column_state(c2,t2_4)" [label="" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#             "4_p4" -> "column_state(c5,1)" [label="" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#             "column_state(c3,2)" -> "5_p8" [label="" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#             "5_p8" -> "column_state(c3,3)" [label="" weight=14 color="#b26e37" tooltip="" labeltooltip=""]
#
#
# /* End of top-level graph */
# }

# %%
generate_pdf(gv_string,"workflow_step_violation")

# %%
from clorm.clingo import Control
from clorm import Predicate, ConstantField, IntegerField

ctrl = Control()
ctrl.load("recipe_model_v4.pl")
#ctrl.add_facts(db)

# %%
class Process(Predicate):
    pid=ConstantField
    name=ConstantField

# %%
ctrl = Control(unifier=[Process])
ctrl.load("recipe_model_v4.pl")

# %%
ctrl.ground([("base",[])])
# Out:
# recipe_model_v4.pl:314:16-19: info: global variable in tuple of aggregate element:
#   RId

# %%
from clorm import FactBase

class Driver(Predicate):
    name=ConstantField

class Item(Predicate):
    name=ConstantField

class Assignment(Predicate):
    item=ConstantField
    driver=ConstantField
    time=IntegerField

ctrl = Control(unifier=[Driver,Item,Assignment])
ctrl.load("quickstart.pl")
    
    
drivers = [ Driver(name=n) for n in ["dave", "morri", "michael" ] ]
items = [ Item(name="item{}".format(i)) for i in range(1,6) ]
instance = FactBase(drivers + items)

# %%
ctrl.add_facts(instance)
ctrl.ground([("base",[])])

# %%
solution=None
def on_model(model):
    global solution     # Note: use `nonlocal` keyword depending on scope
    solution = model.facts(atoms=True)

ctrl.solve(on_model=on_model)
if not solution:
    raise ValueError("No solution found")

# %%
from clorm import ph1_

query=solution.query(Assignment)\
              .where(Assignment.driver == ph1_)\
              .order_by(Assignment.time)

# %%
for d in drivers:
    assignments = list(query.bind(d.name).all())
    if not assignments:
        print("Driver {} is not working today".format(d.name))
    else:
        print("Driver {} must deliver: ".format(d.name))
        for a in assignments:
            print("\t Item {} at time {}".format(a.item, a.time))
# Out:
# Driver dave must deliver:
# 	 Item item5 at time 1
# 	 Item item4 at time 2
# Driver morri must deliver:
# 	 Item item1 at time 1
# 	 Item item2 at time 2
# 	 Item item3 at time 3
# Driver michael is not working today

# %%
import pandas as pd

# %%
import pyparsing as pp

# %%
#relationship will refer to 'track' in all of your examples
relationship = pp.Word(pp.alphas).setResultsName('relationship')

number = pp.Word(pp.nums + '.')
variable = pp.Word(pp.alphas)
# an argument to a relationship can be either a number or a variable
argument = number | variable

# arguments are a delimited list of 'argument' surrounded by parenthesis
arguments= (pp.Suppress('(') + pp.delimitedList(argument) +
            pp.Suppress(')')).setResultsName('arguments')

# a fact is composed of a relationship and it's arguments 
# (I'm aware it's actually more complicated than this
# it's just a simplifying assumption)
fact = (relationship + arguments).setResultsName('facts', listAllMatches=True)

# a sentence is a fact plus a period
sentence = fact + pp.Suppress('.')

# self explanatory
prolog_sentences = pp.OneOrMore(sentence)

# %%
generate_pdf(gv_string,"workflow_step")
# Out:
# Error: workflow_step.gv: syntax error in line 71 near '('
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_10494/4027189535.py in <module>
# ----> 1 generate_pdf(gv_string,"workflow_step")
#
# /tmp/ipykernel_10494/1047901914.py in generate_pdf(gv_string, filename)
#       6     output = filename+".png"
#       7     get_ipython().system('dot -Tpng -o $output $input')
# ----> 8     return Image(filename=output)
#
# ~/anaconda3/envs/jupyter/lib/python3.7/site-packages/IPython/core/display.py in __init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata)
#    1230         self.unconfined = unconfined
#    1231         super(Image, self).__init__(data=data, url=url, filename=filename,
# -> 1232                 metadata=metadata)
#    1233
#    1234         if self.width is None and self.metadata.get('width', {}):
#
# ~/anaconda3/envs/jupyter/lib/python3.7/site-packages/IPython/core/display.py in __init__(self, data, url, filename, metadata)
#     635             self.metadata = {}
#     636
# --> 637         self.reload()
#     638         self._check_data()
#     639
#
# ~/anaconda3/envs/jupyter/lib/python3.7/site-packages/IPython/core/display.py in reload(self)
#    1261         """Reload the raw data from file or URL."""
#    1262         if self.embed:
# -> 1263             super(Image,self).reload()
#    1264             if self.retina:
#    1265                 self._retina_shape()
#
# ~/anaconda3/envs/jupyter/lib/python3.7/site-packages/IPython/core/display.py in reload(self)
#     660         """Reload the raw data from file or URL."""
#     661         if self.filename is not None:
# --> 662             with open(self.filename, self._read_flags) as f:
#     663                 self.data = f.read()
#     664         elif self.url is not None:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'workflow_step.png'

# %%
df_output_str[("column_schema",3)]
# Out:
# [['column_schema', 'cs11', 'name', 'full_name'],
#  ['column_schema', 'cs11', 'data_type', 'text'],
#  ['column_schema', 'cs12', 'name', 'first_name'],
#  ['column_schema', 'cs12', 'data_type', 'text'],
#  ['column_schema', 'cs13', 'name', 'last_name'],
#  ['column_schema', 'cs13', 'data_type', 'text'],
#  ['column_schema', 'cs13_1', 'name', 'ssn'],
#  ['column_schema', 'cs13_1', 'data_type', 'number'],
#  ['column_schema', 'cs14', 'data_type', 'text'],
#  ['column_schema', 'cs15', 'data_type', 'number']]

# %%
x.context.symbolic_atoms.signatures
# Out:
# [('column_schema', 3, True),
#  ('parameter', 3, True),
#  ('process', 2, True),
#  ('process_blueprint', 4, True),
#  ('workflow_step', 3, True),
#  ('step_input_schema', 3, True),
#  ('workflow_input_violation', 3, True),
#  ('step_output_schema', 3, True),
#  ('workflow_output_violation', 3, True),
#  ('dq_problem', 2, True),
#  ('step_dq_problem', 3, True),
#  ('dq_problem_violation', 3, True),
#  ('workflow_input', 5, True),
#  ('output_process', 2, True),
#  ('inject_workflow_step', 1, True),
#  ('inject_violation', 6, True),
#  ('input_process', 2, True),
#  ('recipe', 4, True),
#  ('recipe_input_sink', 2, True),
#  ('recipe_output_sink', 2, True),
#  ('reuse_recipe', 1, True),
#  ('reuse_violation', 4, True),
#  ('inject_violation_checking', 6, True),
#  ('select_workflow_step', 4, True),
#  ('injected_parameter', 4, True),
#  ('process_schema', 5, True),
#  ('workflow_path', 4, True),
#  ('example_flow', 4, True),
#  ('column', 4, True),
#  ('dataset', 2, True),
#  ('array', 2, True),
#  ('parameter', 4, True),
#  ('update_workflow_step', 2, True)]

# %%
for y in x.context.symbolic_atoms.by_signature("column_schema",3):
    print(y.symbol)
# Out:
# column_schema(cs11,name,full_name)
# column_schema(cs11,data_type,text)
# column_schema(cs12,name,first_name)
# column_schema(cs12,data_type,text)
# column_schema(cs13,name,last_name)
# column_schema(cs13,data_type,text)
# column_schema(cs13_1,name,ssn)
# column_schema(cs13_1,data_type,number)
# column_schema(cs14,data_type,text)
# column_schema(cs15,data_type,number)

# %%
for y in x.context.symbolic_atoms.by_signature("workflow_step",3):
    print(y.symbol)
# Out:
# workflow_step(column_state(c11,1),p1,column_state(c11,2))
# workflow_step(column_state(c11,1),p1,column_state(c12,1))
# workflow_step(column_state(c11,1),p1,column_state(c13,1))
# workflow_step(column_state(c12,1),p1,column_state(c12,2))
# workflow_step(column_state(c12,1),p6,column_state(c12,2))
# workflow_step(column_state(c12,1),p6,column_state(c13_1,1))

# %%
for y in x.context.symbolic_atoms.by_signature("step_input_schema",3):
    print(y.symbol)
# Out:
# step_input_schema(column_state(c11,1),p1,column_schema(cs11,name,full_name))
# step_input_schema(column_state(c11,1),p1,column_schema(cs11,data_type,text))
# step_input_schema(column_state(c12,1),p1,column_schema(cs12,name,first_name))
# step_input_schema(column_state(c12,1),p1,column_schema(cs12,data_type,text))
# step_input_schema(column_state(c12,1),p6,column_schema(cs12,name,first_name))
# step_input_schema(column_state(c12,1),p6,column_schema(cs12,data_type,text))

# %%
y.symbol.name
# Out:
# 'step_input_schema'

# %%
str(y.symbol.arguments[0])
# Out:
# 'column_state(c12,1)'

# %%
str(y.symbol.arguments[1])
# Out:
# 'p6'

# %%
str(y.symbol.arguments[2])
# Out:
# 'column_schema(cs12,data_type,text)'

# %%
test = ctl.solve(on_model=on_model)
# Out:
# workflow_input_violation(column_state(c12,1),p1,column_schema(cs11,name,full_name)) workflow_output_violation(column_state(c12,1),p1,column_schema(cs11,name,full_name)) workflow_output_violation(column_state(c12,1),p1,column_schema(cs13,name,last_name)) dq_problem_violation(column_state(c11,1),p1,null_value) dq_problem_violation(column_state(c12,1),p6,date_format_error)

# %%
test.unknown
# Out:
# False

# %%
result = prolog_sentences.parseString(facts)
# Out:
# ---------------------------------------------------------------------------
# ParseException                            Traceback (most recent call last)
# /tmp/ipykernel_173628/4123674497.py in <module>
# ----> 1 result = prolog_sentences.parseString(facts)
#
# ~/anaconda3/envs/jupyter/lib/python3.7/site-packages/pyparsing.py in parseString(self, instring, parseAll)
#    1953                 if getattr(exc, '__traceback__', None) is not None:
#    1954                     exc.__traceback__ = self._trim_traceback(exc.__traceback__)
# -> 1955                 raise exc
#    1956         else:
#    1957             return tokens
#
# ~/anaconda3/envs/jupyter/lib/python3.7/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    2897         if instring[loc] == self.firstMatchChar:
#    2898             return loc + 1, self.match
# -> 2899         raise ParseException(instring, loc, self.errmsg, self)
#    2900
#    2901 _L = Literal
#
# ParseException: Expected ")", found '1'  (at char 9), (line:1, col:10)

# %%
result
# Out:
# (['track', '1', '2.0', '4000', '3', '300', 'track', '2', '1.0', '9000', '5', '500', 'track', '3', '7.0', '9000', '2', '200'], {'relationship': ['track', 'track', 'track'], 'arguments': [(['1', '2.0', '4000', '3', '300'], {}), (['2', '1.0', '9000', '5', '500'], {}), (['3', '7.0', '9000', '2', '200'], {})], 'facts': [(['track', '1', '2.0', '4000', '3', '300'], {}), (['track', '2', '1.0', '9000', '5', '500'], {}), (['track', '3', '7.0', '9000', '2', '200'], {})]})

# %%
test="""track(1, 2.0, 4000, 3, 300).
track(2, 1.0, 9000, 5, 500).
track(3, 7.0, 9000, 2, 200)."""

result = prolog_sentences.parseString(test)

print(result['facts'][0])
# outputs ['1', '2.0', '4000', '3', '300']

print(result['facts'][1]['relationship'])
# outputs 'track'

print(result['facts'][2]['arguments'][1])
# Out:
# ['track', '1', '2.0', '4000', '3', '300']
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_173628/909149491.py in <module>
#       8 # outputs ['1', '2.0', '4000', '3', '300']
#       9
# ---> 10 print(result['facts'][1]['relationship'])
#      11 # outputs 'track'
#      12
#
# ~/anaconda3/envs/jupyter/lib/python3.7/site-packages/pyparsing.py in __getitem__(self, i)
#     596         else:
#     597             if i not in self.__accumNames:
# --> 598                 return self.__tokdict[i][-1][0]
#     599             else:
#     600                 return ParseResults([v[0] for v in self.__tokdict[i]])
#
# KeyError: 'relationship'
